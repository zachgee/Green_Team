# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2 as db_connect
import gmaps
import requests
gmaps.configure(api_key="AIzaSyDa799QehZ72cOrcB4U8B-o4I8-aCBq0vw")

# %%
host_name="dataviz.cgq2ewzuuqs1.us-east-2.rds.amazonaws.com"
db_user="postgres"
db_password="ElPeruano_2021"
db_name="postgres"
db_port = 5432
connection = db_connect.connect(host=host_name,user=db_user,password=db_password,database=db_name, port=db_port)

# %%
cursor = connection.cursor()

# %%
vSQL = 'Select * from public."G_Charging_Stations"'

# %%
cursor.execute(vSQL)
result = cursor.fetchall()

# %%
print(result)
# Out:
# [('CATHERINE / CATHERINE 1', '300 Barton Springs Rd', None, 'Austin', 'Texas', 78704, 2, '$4.17/month PIE members $2/hr Non-Members', 'Multi-family residential', 'Multifamily Commercial', 'Apartment', 'J1772', 'J1772', '30.259096', '-97.747775', 240, 40), ('AUSTIN HQ / STATION 1', '4200 Smith School Dr', None, 'Austin', 'Texas', 78744, 2, '$4.17/month PIE members $2/hr Non-Members', 'Commercial with unrestricted access', 'Workplace', 'General', 'J1772', 'J1772', '30.192647', '-97.714329', 240, 40), ('SCHOOL / AKINS1', '10701 S 1st St.', None, 'Austin', 'Texas', 78748, 2, '$4.17/month PIE members $2/hr Non-Members', 'Public Municipal - library/street/etc ', 'Education', 'High School / Other', 'J1772', 'J1772', '30.147634', '-97.801294', 240, 40), ('MONOGRAM / HANDICAP', '615 W 7th St', None, 'Austin', 'Texas', 78701, 1, '$4.17/month PIE members $2/hr Non-Members', 'Multi-family residential', 'Multifamily Commercial', 'Apartment', 'J1772', '--', '30.270571', '-97.748993', 240, 40), ('F
# ...

# %%
df = pd.DataFrame(result)
df.head(5)
# Out:
#                                  0                      1     2       3   \
# 0           CATHERINE / CATHERINE 1  300 Barton Springs Rd  None  Austin
# 1             AUSTIN HQ / STATION 1   4200 Smith School Dr  None  Austin
# 2                   SCHOOL / AKINS1        10701 S 1st St.  None  Austin
# 3               MONOGRAM / HANDICAP           615 W 7th St  None  Austin
# 4  FLATIRON DOMAIN / FLATIRON DOM 2        10727 domain dr  None  Austin
#
#       4      5   6                                          7   \
# 0  Texas  78704   2  $4.17/month PIE members $2/hr Non-Members
# 1  Texas  78744   2  $4.17/month PIE members $2/hr Non-Members
# 2  Texas  78748   2  $4.17/month PIE members $2/hr Non-Members
# 3  Texas  78701   1  $4.17/month PIE members $2/hr Non-Members
# 4  Texas  78758   2  $4.17/month PIE members $2/hr Non-Members
#
#                                        8                       9   \
# 0                Multi-family residential  Multifamily Commercial
# ...

# %%
df.rename(columns={0: 'Property Name',1:'Address',2:'nan',3:'City',4:'State',5:'Zip Code',6:'Number of Ports',7:'Pricing Policy',8:'Usage Access',9:'Category',10:'Sub Category',11:'Port 1',12:'Port 2',13:'Latitude',14:'Longitude',15:'Voltage',16:'Amps' }, inplace=True)

df.head(5)
# Out:
#                       Property Name                Address   nan    City  \
# 0           CATHERINE / CATHERINE 1  300 Barton Springs Rd  None  Austin
# 1             AUSTIN HQ / STATION 1   4200 Smith School Dr  None  Austin
# 2                   SCHOOL / AKINS1        10701 S 1st St.  None  Austin
# 3               MONOGRAM / HANDICAP           615 W 7th St  None  Austin
# 4  FLATIRON DOMAIN / FLATIRON DOM 2        10727 domain dr  None  Austin
#
#    State  Zip Code  Number of Ports  \
# 0  Texas     78704                2
# 1  Texas     78744                2
# 2  Texas     78748                2
# 3  Texas     78701                1
# 4  Texas     78758                2
#
#                               Pricing Policy  \
# 0  $4.17/month PIE members $2/hr Non-Members
# 1  $4.17/month PIE members $2/hr Non-Members
# 2  $4.17/month PIE members $2/hr Non-Members
# 3  $4.17/month PIE members $2/hr Non-Members
# 4  $4.17/month PIE members $2/hr Non-Members
#
# ...

# %%
Address_df = df.drop(['nan','City','State','Number of Ports','Pricing Policy','Voltage','Port 1','Port 2','Amps'], axis = 1)
Address_df.head(5)
# Out:
#                       Property Name                Address  Zip Code  \
# 0           CATHERINE / CATHERINE 1  300 Barton Springs Rd     78704
# 1             AUSTIN HQ / STATION 1   4200 Smith School Dr     78744
# 2                   SCHOOL / AKINS1        10701 S 1st St.     78748
# 3               MONOGRAM / HANDICAP           615 W 7th St     78701
# 4  FLATIRON DOMAIN / FLATIRON DOM 2        10727 domain dr     78758
#
#                              Usage Access                Category  \
# 0                Multi-family residential  Multifamily Commercial
# 1     Commercial with unrestricted access               Workplace
# 2  Public Municipal - library/street/etc                Education
# 3                Multi-family residential  Multifamily Commercial
# 4                Multi-family residential  Multifamily Commercial
#
#           Sub Category   Latitude   Longitude
# 0            Apartment  30.259096  -97.747775
# 1              General  30.192647  -97.714329
# ...

# %%
Charge_df = df.drop(['Address','nan','City','State','Zip Code','Category','Sub Category','Voltage'], axis = 1)
Charge_df.head(5)
# Out:
#                       Property Name  Number of Ports  \
# 0           CATHERINE / CATHERINE 1                2
# 1             AUSTIN HQ / STATION 1                2
# 2                   SCHOOL / AKINS1                2
# 3               MONOGRAM / HANDICAP                1
# 4  FLATIRON DOMAIN / FLATIRON DOM 2                2
#
#                               Pricing Policy  \
# 0  $4.17/month PIE members $2/hr Non-Members
# 1  $4.17/month PIE members $2/hr Non-Members
# 2  $4.17/month PIE members $2/hr Non-Members
# 3  $4.17/month PIE members $2/hr Non-Members
# 4  $4.17/month PIE members $2/hr Non-Members
#
#                              Usage Access Port 1 Port 2   Latitude  \
# 0                Multi-family residential  J1772  J1772  30.259096
# 1     Commercial with unrestricted access  J1772  J1772  30.192647
# 2  Public Municipal - library/street/etc   J1772  J1772  30.147634
# 3                Multi-family residential  J1772     --  30.270571
# ...

# %%
geo_df = df.drop(['Property Name','Zip Code','nan','City','State','Usage Access','Category','Sub Category','Number of Ports','Pricing Policy','Amps','Voltage','Port 1','Port 2'], axis = 1)

geo_df.head()
# Out:
#                  Address   Latitude   Longitude
# 0  300 Barton Springs Rd  30.259096  -97.747775
# 1   4200 Smith School Dr  30.192647  -97.714329
# 2        10701 S 1st St.  30.147634  -97.801294
# 3           615 W 7th St  30.270571  -97.748993
# 4        10727 domain dr  30.392852  -97.723729

# %%
import plotly.graph_objects as go

mapbox_access_token = "pk.eyJ1IjoicGtkaiIsImEiOiJja3l3YTNrZW4wNmZyMnBtd3lrM2Z3YWRmIn0.GQsKWwbdEUQI9kOQPAmmXA"

fig = go.Figure(go.Scattermapbox(
        lat=geo_df['Latitude'],
        lon=geo_df['Longitude'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=geo_df['Address'],
    ))

fig.update_layout(
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=30.33,
            lon=-97.75
        ),
        pitch=0,
        zoom=10
    )
)

fig.show()
# Out:
# <div>                            <div id="b65ddcd1-f6ca-485e-a777-96d68914f08e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b65ddcd1-f6ca-485e-a777-96d68914f08e")) {                    Plotly.newPlot(                        "b65ddcd1-f6ca-485e-a777-96d68914f08e",                        [{"lat":["30.259096","30.192647","30.147634","30.270571","30.392852","30.39921","30.268028","30.264456","30.207439","30.317689","30.20473","30.266802","30.316576","30.337168","30.277239","30.403822","30.168498","30.347873","30.329139","30.268894","30.470002","30.267392","30.47798","30.271324","30.232256","30.337751","30.259099","30.401656","30.402165","30.389602","30.259647","30.322654","30.351629","30.268719","30.264423","30.404194","30.329076","30.333857","30.23
# ...
